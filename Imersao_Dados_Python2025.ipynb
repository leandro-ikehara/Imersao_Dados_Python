# %% [markdown]
# <a href="https://colab.research.google.com/github/leandro-ikehara/Imersao_Dados_Python/blob/main/Imersao_Dados_Python2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]
print("Linhas:", linhas)
print("Colunas:", colunas)
# Out:
# Linhas: 133349
# Colunas: 11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
colunas = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'USD',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

df.rename(columns=colunas, inplace=True)

print(df.columns)
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'USD',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
contrato = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Tempo Parcial',
    'FL': 'Freelancer'
}

df['contrato'] = df['contrato'].replace(contrato)

display(df['contrato'].value_counts())
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Tempo Parcial        376
# Freelancer            16
# Name: count, dtype: int64

# %%
remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

df['remoto'] = df['remoto'].replace(remoto)

display(df['remoto'].value_counts())
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
tamanho_empresa = {
    'M': 'Médio',
    'L': 'Grande',
    'S': 'Pequeno'
}

df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa)

display(df['tamanho_empresa'].value_counts())
# Out:
# tamanho_empresa
# Médio      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
senioridade = {
    'SE': 'Sênior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

df['senioridade'] = df['senioridade'].replace(senioridade)

display(df['senioridade'].value_counts())
# Out:
# senioridade
# Sênior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       USD residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df.describe(include='object')
# Out:
#        senioridade        contrato           cargo   moeda residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Sênior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Médio
# freq        105312  119641          129561

# %%
df.describe()
# Out:
#                  ano       salario            USD
# count  133339.000000  1.333490e+05  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098
# std         0.680627  2.173860e+05   74288.363097
# min      2020.000000  1.400000e+04   15000.000000
# 25%      2024.000000  1.060200e+05  106000.000000
# 50%      2024.000000  1.470000e+05  146206.000000
# 75%      2025.000000  1.990000e+05  198000.000000
# max      2025.000000  3.040000e+07  800000.000000

# %%
df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    USD  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# USD                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade        contrato                      cargo  salario  \
# 5588    NaN      Sênior  Tempo Integral            Product Manager   184500
# 59692   NaN       Pleno  Tempo Integral                   Engineer   110000
# 59710   NaN      Júnior  Tempo Integral             Data Scientist   208800
# 59759   NaN      Sênior  Tempo Integral          Software Engineer   135000
# 59789   NaN      Sênior  Tempo Integral                   Engineer   112000
# 131000  NaN      Sênior  Tempo Integral  Machine Learning Engineer   163800
# 131006  NaN      Sênior  Tempo Integral     Data Analytics Manager   204500
# 133054  NaN      Júnior  Tempo Integral             Data Scientist    40000
# 133281  NaN       Pleno  Tempo Integral  Machine Learning Engineer   180000
# 133317  NaN       Pleno  Tempo Integral             Data Scientist   130000
#
#        moeda     USD residencia      remoto empresa tamanho_empresa
# ...

# %%
import numpy as np

#criação de dataframe de teste
df_salarios = pd.DataFrame({
    'nome': ['Leandro', 'Ana Paula', 'Patricia', 'Leticia', 'Pedro'],
    'salario': [4000, np.nan, 5000, np.nan, 10000]
    })

#dataframe que calcula a média do salário
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

#dataframe que calcula a mediana dos salários
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())
display(df_salarios)
# Out:
#         nome  salario  salario_media  salario_mediana
# 0    Leandro   4000.0        4000.00           4000.0
# 1  Ana Paula      NaN        6333.33           5000.0
# 2   Patricia   5000.0        5000.00           5000.0
# 3    Leticia      NaN        6333.33           5000.0
# 4      Pedro  10000.0       10000.00          10000.0

# %%
df_temperaturas = pd.DataFrame({
    'Dia': ['Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta'],
    'Temperatura': [30, np.nan, np.nan, 28, 27]
})
df_temperaturas['Preenchido_ffill'] = df_temperaturas['Temperatura'].ffill()
df_temperaturas['Preenchido_bfill'] = df_temperaturas['Temperatura'].bfill()
display(df_temperaturas)
# Out:
#        Dia  Temperatura  Preenchido_ffill  Preenchido_bfill
# 0  Segunda         30.0              30.0              30.0
# 1    Terça          NaN              30.0              28.0
# 2   Quarta          NaN              30.0              28.0
# 3   Quinta         28.0              28.0              28.0
# 4    Sexta         27.0              27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'Nome': ['Leandro', 'Ana Paula', 'Patricia', 'Leticia', 'Pedro'],
    'Cidade': ['São Paulo', np.nan, 'Belo Horizonte', np.nan, 'Curitiba']

})
df_cidades['cidade_preenchida'] = df_cidades['Cidade'].fillna('Não informado')
df_cidades
# Out:
#         Nome          Cidade cidade_preenchida
# 0    Leandro       São Paulo         São Paulo
# 1  Ana Paula             NaN     Não informado
# 2   Patricia  Belo Horizonte    Belo Horizonte
# 3    Leticia             NaN     Não informado
# 4      Pedro        Curitiba          Curitiba

# %%
df_tratado = df.dropna()
df_tratado.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# USD                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_tratado.head()
# Out:
#       ano senioridade        contrato               cargo  salario moeda  \
# 0  2025.0      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       USD residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   USD              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
df_tratado = df_tratado.assign(ano = df_tratado['ano'].astype('int64'))

# %%
df_tratado.head()
# Out:
#     ano senioridade        contrato               cargo  salario moeda  \
# 0  2025      Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025      Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025       Pleno  Tempo Integral       Data Engineer   158800   USD
# 3  2025       Pleno  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Júnior  Tempo Integral       Data Engineer    90000   USD
#
#       USD residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Médio
# 1  136000         US      Remoto      US           Médio
# 2  158800         AU  Presencial      AU           Médio
# 3  139200         AU  Presencial      AU           Médio
# 4   90000         US  Presencial      US           Médio

# %%
df_tratado['senioridade'].value_counts().plot(kind='bar', title='Senioridade')
# Out:
# <Axes: title={'center': 'Senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
sns.barplot(data=df_tratado, x='senioridade', y='USD')
plt.title('Salário anual em Dólar por Senioridade')
# Out:
# Text(0.5, 1.0, 'Salário anual em Dólar por Senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_tratado, x='senioridade', y='USD')
plt.title('Salário anual em Dólar por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual em Dólar')
plt.show()

# %%
df_tratado.groupby('senioridade')['USD'].mean().sort_values(ascending=False)
# Out:
# senioridade
# Executivo    202027.667813
# Sênior       172850.838301
# Pleno        143044.845979
# Júnior        99034.963267
# Name: USD, dtype: float64

# %%
ordenamento = df_tratado.groupby('senioridade')['USD'].mean().sort_values(ascending=False).index
# sns.barplot(data=df_tratado, x='senioridade', y='USD', order=ordenamento)
# plt.title('Salário anual em Dólar por Senioridade')
ordenamento
# Out:
# Index(['Executivo', 'Sênior', 'Pleno', 'Júnior'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df_tratado, x='senioridade', y='USD', order=ordenamento)
plt.title('Salário anual em Dólar por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual em Dólar')
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_tratado['USD'], bins= 50, kde=True)
plt.title('Salário anual em Dólar')
plt.xlabel('Salário em US$')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_tratado['USD'])
plt.title('Salário anual em Dólar')
plt.show()

# %%
ordenacao_senioridade = ['Júnior','Pleno','Sênior','Executivo']
plt.figure(figsize=(8, 5))
sns.boxplot(x='senioridade', y='USD', data=df_tratado, order=ordenacao_senioridade)
plt.title('Distribuição por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual em Dólar')
plt.show()

# %%
ordenacao_senioridade = ['Júnior','Pleno','Sênior','Executivo']
plt.figure(figsize=(8, 5))
sns.boxplot(x='senioridade', y='USD', data=df_tratado, order=ordenacao_senioridade, palette='Set1', hue='senioridade')
plt.title('Distribuição por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário médio anual em Dólar')
plt.show()

# %%
fig = px.bar(df_tratado.groupby('senioridade')['USD'].mean().reset_index(),
             x='senioridade',
             y='USD',
             title='Salário médio anual em Dólar por Senioridade',
             labels={'senioridade': 'Senioridade', 'USD': 'Salário médio anual em Dólar'},
             category_orders={'senioridade': ['Júnior', 'Pleno', 'Sênior', 'Executivo']})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_frequencia = df_tratado['remoto'].value_counts().reset_index()
remoto_frequencia.columns = ['tipo_trabalho', 'quantidade']
remoto_frequencia

fig = px.pie(remoto_frequencia,
             values='quantidade',
             names='tipo_trabalho',
             title='Proporção por tipo de trabalho')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_frequencia = df_tratado['remoto'].value_counts().reset_index()
remoto_frequencia.columns = ['tipo_trabalho', 'quantidade']
remoto_frequencia

fig = px.pie(remoto_frequencia,
             values='quantidade',
             names='tipo_trabalho',
             title='Proporção por tipo de trabalho',
             hole=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_frequencia = df_tratado['remoto'].value_counts().reset_index()
remoto_frequencia.columns = ['tipo_trabalho', 'quantidade']
remoto_frequencia

fig = px.pie(remoto_frequencia,
             values='quantidade',
             names='tipo_trabalho',
             title='Proporção por tipo de trabalho',
             hole=0.3)
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Desafio da aula: **
#
# Criar um gráfico interativo, exibindo salário médio x país do cargo de Cientista de Dados.

# %%
cargos_traduzidos = {
    'Data Scientist': 'Cientista de Dados',
    'Other': 'Outro',
    'Data Analyst': 'Analista de Dados',
    'Machine Learning Engineer': 'Engenheiro de Machine Learning',
    'Data Engineer': 'Engenheiro de Dados',
    'Analytics Engineer': 'Engenheiro de Análise',
    'AI Engineer': 'Engenheiro de IA',
    'BI Analyst': 'Analista de BI',
    'Research Scientist': 'Cientista de Pesquisa',
    'Data Architect': 'Arquiteto de Dados',
    'Data Manager': 'Gerente de Dados',
    'Machine Learning Scientist': 'Cientista de Machine Learning',
    'Data Science Manager': 'Gerente de Ciência de Dados',
    'Business Intelligence Engineer': 'Engenheiro de Business Intelligence',
    'ML Engineer': 'Engenheiro de ML',
    'Lead Data Scientist': 'Cientista de Dados Líder',
    'Data Science Lead': 'Líder de Ciência de Dados',
    'Computer Vision Engineer': 'Engenheiro de Visão Computacional',
    'Principal Data Scientist': 'Cientista de Dados Principal',
    'Data Analytics Manager': 'Gerente de Análise de Dados',
    'Applied Scientist': 'Cientista Aplicado',
    'Director of Data Science': 'Diretor de Ciência de Dados',
    'Head of Data': 'Chefe de Dados',
    'Data Analytics Lead': 'Líder de Análise de Dados',
    'Financial Analyst': 'Analista Financeiro',
    'Consultant': 'Consultor',
    'Manager': 'Gerente',
    'Data Visualization Specialist': 'Especialista em Visualização de Dados',
    'AI Developer': 'Desenvolvedor de IA',
    'Head of Data Science': 'Chefe de Ciência de Dados',
    'Product Data Scientist': 'Cientista de Dados de Produto',
    'Marketing Analyst': 'Analista de Marketing',
    'Data Integration Specialist': 'Especialista em Integração de Dados',
    'Data Strategy Manager': 'Gerente de Estratégia de Dados',
    'Business Data Analyst': 'Analista de Dados de Negócios',
    'Compliance Analyst': 'Analista de Conformidade',
    'Data Science Consultant': 'Consultor de Ciência de Dados',
    'Machine Learning Researcher': 'Pesquisador de Machine Learning',
    'Data DevOps Engineer': 'Engenheiro de Data DevOps',
    'Data Quality Analyst': 'Analista de Qualidade de Dados',
    'Cloud Data Engineer': 'Engenheiro de Dados em Nuvem',
    'Data Product Manager': 'Gerente de Produto de Dados',
    'Data Visualization Engineer': 'Engenheiro de Visualização de Dados',
    'Data Science Instructor': 'Instrutor de Ciência de Dados',
    'Software Engineer': 'Engenheiro de Software',
    'Data Quality Engineer': 'Engenheiro de Qualidade de Dados',
    'MLOps Engineer': 'Engenheiro de MLOps',
    'Data Science Architect': 'Arquiteto de Ciência de Dados',
    'Data Scientist Lead': 'Líder Cientista de Dados',
    'Big Data Engineer': 'Engenheiro de Big Data',
    'AI Architect': 'Arquiteto de IA',
    'Head of Machine Learning': 'Chefe de Machine Learning',
    'Data Analytics Specialist': 'Especialista em Análise de Dados',
    'Principal Data Engineer': 'Engenheiro de Dados Principal',
    'BI Developer': 'Desenvolvedor de BI',
    'Data Analytics Consultant': 'Consultor de Análise de Dados',
    'Data Infrastructure Engineer': 'Engenheiro de Infraestrutura de Dados',
    'Business Intelligence Analyst': 'Analista de Business Intelligence',
    'Data Modeler': 'Modelador de Dados',
    'Data Operations Engineer': 'Engenheiro de Operações de Dados',
    'Data Operations Analyst': 'Analista de Operações de Dados',
    'Principal Data Analyst': 'Analista de Dados Principal',
    'Applied Data Scientist': 'Cientista de Dados Aplicado',
    'BI Data Analyst': 'Analista de Dados de BI',
    'Data Science Practitioner': 'Profissional de Ciência de Dados',
    'Machine Learning Modeler': 'Modelador de Machine Learning',
    'Data Science Manager': 'Gerente de Ciência de Dados', # Duplicate, will be handled by dict
    'Data Science Director': 'Diretor de Ciência de Dados',
    'Head of Data Science': 'Chefe de Ciência de Dados', # Duplicate, will be handled by dict
    'ETL Developer': 'Desenvolvedor de ETL',
    'Data Lead': 'Líder de Dados',
    'Data Science Manager': 'Gerente de Ciência de Dados', # Duplicate, will be handled by dict
    'Data Science Consultant': 'Consultor de Ciência de Dados', # Duplicate, will be handled by dict
    'Data Science Engineer': 'Engenheiro de Ciência de Dados',
    'Data Science Instructor': 'Instrutor de Ciência de Dados', # Duplicate, will be handled by dict
    'Data Science Practitioner': 'Profissional de Ciência de Dados', # Duplicate, will be handled by dict
    'Machine Learning Infrastructure Engineer': 'Engenheiro de Infraestrutura de Machine Learning',
    'Machine Learning Operations Engineer': 'Engenheiro de Operações de Machine Learning',
    'NLP Engineer': 'Engenheiro de PLN',
    'Principal Machine Learning Engineer': 'Engenheiro de Machine Learning Principal',
    'Staff Data Scientist': 'Cientista de Dados de Equipe',
    'Big Data Architect': 'Arquiteto de Big Data',
    'Computer Vision Software Engineer': 'Engenheiro de Software de Visão Computacional',
    'Data Analyst Lead': 'Líder de Análise de Dados',
    'Data Management Analyst': 'Analista de Gerenciamento de Dados',
    'Marketing Data Analyst': 'Analista de Dados de Marketing',
    'Power BI Developer': 'Desenvolvedor de Power BI',
    'Principal Data Analyst': 'Analista de Dados Principal', # Duplicate, will be handled by dict
    'Product Data Analyst': 'Analista de Dados de Produto',
    'Financial Data Analyst': 'Analista de Dados Financeiros',
    'AI Programmer': 'Programador de IA',
    'Data Science Tech Lead': 'Líder Técnico de Ciência de Dados',
    'Lead Data Engineer': 'Engenheiro de Dados Líder',
    'Data Science Fellow': 'Bolsista de Ciência de Dados',
    'Data Science Specialist': 'Especialista em Ciência de Dados',
    'Manager Data Analytics': 'Gerente de Análise de Dados',
    'BI Analyst Lead': 'Líder de Analista de BI',
    'Data Analytics Architect': 'Arquiteto de Análise de Dados',
    'Data Science Manager': 'Gerente de Ciência de Dados', # Duplicate, will be handled by dict
    'Data Scientist Principal': 'Cientista de Dados Principal',
    'Machine Learning Manager': 'Gerente de Machine Learning',
    'Principal Machine Learning Scientist': 'Cientista de Machine Learning Principal',
    'AI Research Scientist': 'Cientista de Pesquisa de IA',
    'Analytics Manager': 'Gerente de Análise',
    'Data Engineer Lead': 'Líder Engenheiro de Dados',
    'Data Management Specialist': 'Especialista em Gerenciamento de Dados',
    'Data Science Manager': 'Gerente de Ciência de Dados', # Duplicate, will be handled by dict
    'Head of Financial Data': 'Chefe de Dados Financeiros',
    'Lead Data Analyst': 'Líder Analista de Dados',
    'Lead Machine Learning Engineer': 'Líder Engenheiro de Machine Learning',
    'Machine Learning Engineer Lead': 'Líder Engenheiro de Machine Learning', # Duplicate, will be handled by dict
    'Principal Data Architect': 'Arquiteto de Dados Principal',
    'Principal Data Scientist': 'Cientista de Dados Principal', # Duplicate, will be handled by dict
    'Applied Machine Learning Scientist': 'Cientista de Machine Learning Aplicado',
    'Data Architect Lead': 'Líder Arquiteto de Dados',
    'Data Science Manager': 'Gerente de Ciência de Dados', # Duplicate, will be handled by dict
    'Director of Data Engineering': 'Diretor de Engenharia de Dados',
    'ETL Engineer': 'Engenheiro de ETL',
    'Head of Analytics': 'Chefe de Análise',
    'Machine Learning Analyst': 'Analista de Machine Learning',
    'Machine Learning Infrastructure Engineer': 'Engenheiro de Infraestrutura de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Software Engineer': 'Engenheiro de Software de Machine Learning',
    'Principal Data Engineer': 'Engenheiro de Dados Principal', # Duplicate, will be handled by dict
    'Principal Data Scientist': 'Cientista de Dados Principal', # Duplicate, will be handled by dict
    'Staff Data Analyst': 'Analista de Dados de Equipe',
    'Staff Data Engineer': 'Engenheiro de Dados de Equipe',
    'Applied Data Engineer': 'Engenheiro de Dados Aplicado',
    'Applied Machine Learning Engineer': 'Engenheiro de Machine Learning Aplicado',
    'Data Analytics Manager': 'Gerente de Análise de Dados', # Duplicate, will be handled by dict
    'Data Analytics Scientist': 'Cientista de Análise de Dados',
    'Data Science Manager': 'Gerente de Ciência de Dados', # Duplicate, will be handled by dict
    'Director of Data Analytics': 'Diretor de Análise de Dados',
    'Financial Data Scientist': 'Cientista de Dados Financeiros',
    'Head of Data Science': 'Chefe de Ciência de Dados', # Duplicate, will be handled by dict
    'Lead Data Scientist': 'Cientista de Dados Líder', # Duplicate, will be handled by dict
    'Lead Data Analyst': 'Líder Analista de Dados', # Duplicate, will be handled by dict
    'Lead Data Engineer': 'Engenheiro de Dados Líder', # Duplicate, will be handled by dict
    'Machine Learning Engineer Lead': 'Líder Engenheiro de Machine Learning',
    'NLP Scientist': 'Cientista de PLN',
    'Principal Analytics Engineer': 'Engenheiro de Análise Principal',
    'Principal Data Architect': 'Arquiteto de Dados Principal', # Duplicate, will be handled by dict
    'Principal Data Engineer': 'Engenheiro de Dados Principal', # Duplicate, will be handled by dict
    'Principal Data Scientist': 'Cientista de Dados Principal', # Duplicate, will be handled by dict
    'Staff Machine Learning Engineer': 'Engenheiro de Machine Learning de Equipe',
    'Analytics Engineer Lead': 'Líder Engenheiro de Análise',
    'Data Architect Manager': 'Gerente Arquiteto de Dados',
    'Data Infrastructure Engineer': 'Engenheiro de Infraestrutura de Dados', # Duplicate, will be handled by dict
    'Data Management Specialist': 'Especialista em Gerenciamento de Dados', # Duplicate, will be handled by dict
    'Data Science Consultant': 'Consultor de Ciência de Dados', # Duplicate, will be handled by dict
    'Director of Data Science': 'Diretor de Ciência de Dados', # Duplicate, will be handled by dict
    'Head of Data': 'Chefe de Dados', # Duplicate, will be handled by dict
    'Head of Data Science': 'Chefe de Ciência de Dados', # Duplicate, will be handled by dict
    'Lead Data Scientist': 'Cientista de Dados Líder', # Duplicate, will be handled by dict
    'Lead Machine Learning Engineer': 'Líder Engenheiro de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Infrastructure Engineer': 'Engenheiro de Infraestrutura de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Manager': 'Gerente de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Operations Engineer': 'Engenheiro de Operações de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Scientist': 'Cientista de Machine Learning', # Duplicate, will be handled by dict
    'Principal Data Analyst': 'Analista de Dados Principal', # Duplicate, will be handled by dict
    'Principal Data Engineer': 'Engenheiro de Dados Principal', # Duplicate, will be handled by dict
    'Principal Data Scientist': 'Cientista de Dados Principal', # Duplicate, will be handled by dict
    'Staff Data Analyst': 'Analista de Dados de Equipe', # Duplicate, will be handled by dict
    'Staff Data Engineer': 'Engenheiro de Dados de Equipe', # Duplicate, will be handled by dict
    'Staff Machine Learning Engineer': 'Engenheiro de Machine Learning de Equipe', # Duplicate, will be handled by dict
    'AI Specialist': 'Especialista em IA',
    'Applied Scientist': 'Cientista Aplicado', # Duplicate, will be handled by dict
    'Business Data Scientist': 'Cientista de Dados de Negócios',
    'Data Analytics Specialist': 'Especialista em Análise de Dados', # Duplicate, will be handled by dict
    'Data Integration Engineer': 'Engenheiro de Integração de Dados',
    'Data Modeler': 'Modelador de Dados', # Duplicate, will be handled by dict
    'Data Quality Engineer': 'Engenheiro de Qualidade de Dados', # Duplicate, will be handled by dict
    'Data Science Manager': 'Gerente de Ciência de Dados', # Duplicate, will be handled by dict
    'Data Science Tech Lead': 'Líder Técnico de Ciência de Dados', # Duplicate, will be handled by dict
    'Data Scientist Lead': 'Líder Cientista de Dados', # Duplicate, will be handled by dict
    'Director of Data Engineering': 'Diretor de Engenharia de Dados', # Duplicate, will be handled by dict
    'ETL Developer': 'Desenvolvedor de ETL', # Duplicate, will be handled by dict
    'Finance Data Analyst': 'Analista de Dados Financeiros',
    'Head of Analytics': 'Chefe de Análise', # Duplicate, will be handled by dict
    'Head of Data': 'Chefe de Dados', # Duplicate, will be handled by dict
    'Head of Data Science': 'Chefe de Ciência de Dados', # Duplicate, will be handled by dict
    'Lead Data Analyst': 'Líder Analista de Dados', # Duplicate, will be handled by dict
    'Lead Data Engineer': 'Engenheiro de Dados Líder', # Duplicate, will be handled by dict
    'Lead Data Scientist': 'Cientista de Dados Líder', # Duplicate, will be handled by dict
    'Lead Machine Learning Engineer': 'Líder Engenheiro de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Infrastructure Engineer': 'Engenheiro de Infraestrutura de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Operations Engineer': 'Engenheiro de Operações de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Scientist': 'Cientista de Machine Learning', # Duplicate, will be handled by dict
    'Machine Learning Software Engineer': 'Engenheiro de Software de Machine Learning', # Duplicate, will be handled by dict
    'NLP Engineer': 'Engenheiro de PLN', # Duplicate, will be handled by dict
    'Principal Analytics Engineer': 'Engenheiro de Análise Principal', # Duplicate, will be handled by dict
    'Principal Data Architect': 'Arquiteto de Dados Principal', # Duplicate, will be handled by dict
    'Principal Data Engineer': 'Engenheiro de Dados Principal', # Duplicate, will be handled by dict
    'Principal Data Scientist': 'Cientista de Dados Principal', # Duplicate, will be handled by dict
    'Research Scientist': 'Cientista de Pesquisa', # Duplicate, will be handled by dict
    'Staff Data Analyst': 'Analista de Dados de Equipe', # Duplicate, will be handled by dict
    'Staff Data Engineer': 'Engenheiro de Dados de Equipe', # Duplicate, will be handled by dict
    'Staff Data Scientist': 'Cientista de Dados de Equipe', # Duplicate, will be handled by dict
    'Staff Machine Learning Engineer': 'Engenheiro de Machine Learning de Equipe', # Duplicate, will be handled by dict
    'Solutions Architect': 'Arquiteto de Soluções',
    'Solutions Engineer': 'Engenheiro de Soluções'
}

df_tratado['cargo'] = df_tratado['cargo'].replace(cargos_traduzidos)

display(df_tratado['cargo'].value_counts())
# Out:
# cargo
# Cientista de Dados                          17312
# Engenheiro de Software                      15006
# Engenheiro de Dados                         14868
# Analista de Dados                           12381
# Engineer                                     9454
#                                             ...
# CRM Data Analyst                                1
# Quantitative Research Analyst                   1
# Marketing Data Scientist                        1
# Engenheiro de Machine Learning de Equipe        1
# Cloud Data Architect                            1
# Name: count, Length: 387, dtype: int64

# %%
# Create a dictionary for country code to Brazilian Portuguese translation (including common countries and 'Other')
residencia_traduzida = {
    'US': 'Estados Unidos',
    'GB': 'Reino Unido',
    'CA': 'Canadá',
    'DE': 'Alemanha',
    'IN': 'Índia',
    'FR': 'França',
    'ES': 'Espanha',
    'AU': 'Austrália',
    'BR': 'Brasil',
    'NL': 'Holanda',
    'JP': 'Japão',
    'IT': 'Itália',
    'PL': 'Polônia',
    'RU': 'Rússia',
    'TR': 'Turquia',
    'PK': 'Paquistão',
    'UA': 'Ucrânia',
    'IE': 'Irlanda',
    'CH': 'Suíça',
    'CZ': 'República Tcheca',
    'DK': 'Dinamarca',
    'SE': 'Suécia',
    'AT': 'Áustria',
    'NG': 'Nigéria',
    'GR': 'Grécia',
    'AE': 'Emirados Árabes Unidos',
    'PT': 'Portugal',
    'CO': 'Colômbia',
    'SG': 'Cingapura',
    'MX': 'México',
    'IL': 'Israel',
    'CL': 'Chile',
    'RO': 'Romênia',
    'HR': 'Croácia',
    'NZ': 'Nova Zelândia',
    'HU': 'Hungria',
    'PH': 'Filipinas',
    'BE': 'Bélgica',
    'MY': 'Malásia',
    'EE': 'Estônia',
    'IR': 'Irã',
    'AS': 'Samoa Americana',
    'DZ': 'Argélia',
    'AR': 'Argentina',
    'IQ': 'Iraque',
    'PR': 'Porto Rico',
    'BO': 'Bolívia',
    'BS': 'Bahamas',
    'CR': 'Costa Rica',
    'LU': 'Luxemburgo',
    'MD': 'Moldávia',
    'MT': 'Malta',
    'PU': 'Porto Rico', # Duplicate of PR, will be handled by dict
    'KE': 'Quênia',
    'SI': 'Eslovênia',
    'JE': 'Jersey',
    'VN': 'Vietnã',
    'AD': 'Andorra',
    'CI': 'Costa do Marfim',
    'HK': 'Hong Kong',
    'KR': 'Coreia do Sul',
    'LV': 'Letônia',
    'LI': 'Liechtenstein',
    'MA': 'Marrocos',
    'AO': 'Angola',
    'CY': 'Chipre',
    'EE': 'Estônia', # Duplicate of EE, will be handled by dict
    'GG': 'Guernsey',
    'HN': 'Honduras',
    'KG': 'Quirguistão',
    'MK': 'Macedônia do Norte',
    'MU': 'Maurício',
    'NP': 'Nepal',
    'PE': 'Peru',
    'SK': 'Eslováquia',
    'TH': 'Tailândia',
    'UG': 'Uganda',
    'ZA': 'África do Sul',
    'AM': 'Armênia',
    'BA': 'Bósnia e Herzegovina',
    'BG': 'Bulgária',
    'BY': 'Belarus',
    'CD': 'República Democrática do Congo',
    'CF': 'República Centro-Africana',
    'CM': 'Camarões',
    'CU': 'Cuba',
    'DO': 'República Dominicana',
    'EC': 'Equador',
    'GP': 'Guadalupe',
    'GU': 'Guam',
    'IQ': 'Iraque', # Duplicate of IQ, will be handled by dict
    'KG': 'Quirguistão', # Duplicate of KG, will be handled by dict
    'KZ': 'Cazaquistão',
    'LA': 'Laos',
    'LK': 'Sri Lanka',
    'MD': 'Moldávia', # Duplicate of MD, will be handled by dict
    'ME': 'Montenegro',
    'MQ': 'Martinica',
    'MV': 'Maldivas',
    'MZ': 'Moçambique',
    'NI': 'Nicarágua',
    'PA': 'Panamá',
    'PY': 'Paraguai',
    'RE': 'Reunião',
    'RS': 'Sérvia',
    'RW': 'Ruanda',
    'SI': 'Eslovênia', # Duplicate of SI, will be handled by dict
    'TJ': 'Tajiquistão',
    'TN': 'Tunísia',
    'UZ': 'Uzbequistão',
    'VN': 'Vietnã', # Duplicate of VN, will be handled by dict
    'XK': 'Kosovo',
    'YT': 'Mayotte'

}

df_tratado['residencia'] = df_tratado['residencia'].replace(residencia_traduzida)

display(df_tratado['residencia'].value_counts())
# Out:
# residencia
# Estados Unidos     119572
# Canadá               5238
# Reino Unido          3711
# Austrália             517
# Holanda               404
#                     ...
# KW                      1
# Samoa Americana         1
# CN                      1
# Iraque                  1
# Jersey                  1
# Name: count, Length: 102, dtype: int64

# %%
df_cientista_de_dados = df_tratado[df_tratado['cargo'] == 'Cientista de Dados']
df_cientista_de_dados_por_residencia = df_cientista_de_dados.groupby('residencia')['USD'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(df_cientista_de_dados_por_residencia,
             x='residencia',
             y='USD',
             title='Salário médio anual em Dólar para Cientistas de Dados por Residência',
             labels={'residencia': 'País de Residência', 'USD': 'Salário médio anual em Dólar'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
